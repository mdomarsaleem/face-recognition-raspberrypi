# %%
import numpy as np
import cv2

# %%
im = np.load('/home/mckc/all_test/Abhay_10.npy')
plt.imshow(im)
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-2-6a7549f89321> in <module>()
# ----> 1 im = np.load('/home/mckc/all_test/Abhay_10.npy')
#       2 plt.imshow(im)
#
# /home/mckc/anaconda/lib/python2.7/site-packages/numpy/lib/npyio.pyc in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     360     own_fid = False
#     361     if isinstance(file, basestring):
# --> 362         fid = open(file, "rb")
#     363         own_fid = True
#     364     else:
#
# IOError: [Errno 2] No such file or directory: '/home/mckc/all_test/Abhay_10.npy'

# %%
image = cv2.imread('/home/mckc/All Data/Abhay_cap_specs_0.jpg') 
plt.imshow(image)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
face_cascade = cv2.CascadeClassifier('/home/mckc/Downloads/opencv-2.4.13/data/haarcascades_GPU/haarcascade_frontalface_default.xml')

faces  = face_cascade.detectMultiScale(image,scaleFactor=1.3,minNeighbors=5,minSize=(70, 70))
for (x,y,w,h) in faces:
    fac_cv = np.array(image)[y:(y+h),x:(x+h)]
plt.imshow(fac_cv)

# %%
import dlib

detector = dlib.get_frontal_face_detector()
faces = detector(image, 1)
for a,b in enumerate(faces):
    fac_dlib = np.array(image)[b.top():b.bottom(),b.left():b.right(),:]
plt.imshow(fac_dlib)

# %%
print fac_dlib.shape,fac_cv.shape
# Out:
# (799, 799, 3) (945, 945, 3)

# %%
from skimage.transform import resize

n_fac_dlib = resize(fac_dlib,(224,224,3))
n_fac_cv = resize(fac_cv,(224,224,3))

# %%
plt.imshow(n_fac_cv)

# %%
plt.imshow(n_fac_dlib)
